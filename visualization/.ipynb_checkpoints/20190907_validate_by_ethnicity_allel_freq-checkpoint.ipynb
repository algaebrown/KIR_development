# %%
# restore H.norm and W to impute
import pandas as pd
H_norm = pd.read_csv('~/Data/liger_output/TCGA_5000_hnorm.csv', header = 0, index_col = 0)

# %%
H_norm.head()
# Out:
#                     V1        V2        V3        V4        V5        V6  \
# TCGA-TM-A84O  0.000000  0.000000  0.004726  0.000079  0.000000  0.000000
# TCGA-BF-AAP2  0.000000  0.000000  0.008301  0.000073  0.000000  0.000000
# TCGA-EJ-7794  0.021500  0.024170  0.005403  0.015434  0.011278  0.006177
# TCGA-CV-A45Q  0.019262  0.023861  0.001450  0.016922  0.008791  0.014174
# TCGA-DH-5140  0.000000  0.000000  0.007134  0.000000  0.000000  0.000000
#
#                     V7        V8        V9       V10       V11       V12
# TCGA-TM-A84O  0.017302  0.019183  0.004068  0.018571  0.000000  0.006775
# TCGA-BF-AAP2  0.011007  0.013944  0.004707  0.019546  0.000000  0.006719
# TCGA-EJ-7794  0.003169  0.004546  0.000588  0.015342  0.004595  0.000235
# TCGA-CV-A45Q  0.008486  0.009466  0.002330  0.010254  0.021015  0.003093
# TCGA-DH-5140  0.013405  0.003905  0.007575  0.019797  0.000000  0.007609

# %%
W = pd.read_csv('~/Data/liger_output/TCGA_5000_w.csv', header = 0, index_col = 0)

# %%
W.head()
# Out:
#    TGTCTGCCTGGCCCAGCTCT  TCTGCCTGGCCCAGCTCTGT  CCAGCTCTGTGGTGCCTCCA  \
# 1              0.000000              0.000000              0.000000
# 2              3.854987              4.133120              3.483612
# 3              0.000000              0.000000              0.000000
# 4              0.000000              0.194937              0.000000
# 5              0.000000              0.000000              0.000000
#
#    CAGCTCTGTGGTGCCTCCAG  AGCTCTGTGGTGCCTCCAGG  GCTCTGTGGTGCCTCCAGGA  \
# 1              0.000000              0.000000              0.000000
# 2              3.468414              3.487237              3.496474
# 3              0.000000              0.000000              0.000000
# 4              0.000000              0.000000              0.000000
# 5              0.000000              0.000000              0.000000
#
#    CTCTGTGGTGCCTCCAGGAC  TCTGTGGTGCCTCCAGGACA  CTGTGGTGCCTCCAGGACAT  \
# 1              0.000000              0.000000              0.401420
# 2              3.467066              3.193378              2.076457
# 3              0.000000              0.000000              0.000000
# 4              0.000000              0.120177              1.213296
# 5              0.000000              0.000000              0.000000
#
#    TGTGGTGCCTCCAGGACATG  ...  TGGGTCACTAAGGTCTGACC  GTGGGTCACTAAGGTCTGAC  \
# 1              0.000000  ...              2.930888              2.880032
# 2              1.817816  ...              1.337156              1.308703
# 3              0.000000  ...              0.000000              0.000000
# 4              2.378857  ...              4.317560              4.369497
# 5              0.000000  ...              0.592720              0.573106
#
#    AGTGGGTCACTAAGGTCTGA  CAGTGGGTCACTAAGGTCTG  GCAGTGGGTCACTAAGGTCT  \
# 1              2.595024              2.536716              2.410823
# 2              1.457340              1.555876              1.646847
# 3              0.000000              0.000000              0.000000
# 4              4.331804              4.482808              4.602160
# 5              0.702889              0.841672              0.695893
#
#    AGCAGTGGGTCACTAAGGTC  AAGCAGTGGGTCACTAAGGT  CAAGCAGTGGGTCACTAAGG  \
# 1              2.369528              2.310621              2.148018
# 2              1.619650              1.726003              1.682072
# 3              0.000000              0.000000              0.000000
# 4              4.616234              4.782646              4.802512
# 5              0.696588              0.806944              0.814189
#
#    ACAAGCAGTGGGTCACTAAG  ACCTGTAATCACGATGTCCA
# 1              1.985469              3.207009
# 2              1.516203              1.678243
# 3              0.000000              1.600541
# 4              4.782026              0.000000
# 5              0.983984              4.665028
#
# [5 rows x 2828 columns]

# %%
import numpy as np
restored = np.matmul(H_norm.to_numpy(), W.to_numpy())

# %%
restored_df = pd.DataFrame(restored, columns = W.columns, index = H_norm.index)

# %%
restored_df.head()
# Out:
#               TGTCTGCCTGGCCCAGCTCT  TCTGCCTGGCCCAGCTCTGT  \
# TCGA-TM-A84O              0.824301              0.853009
# TCGA-BF-AAP2              0.648933              0.686908
# TCGA-EJ-7794              0.382805              0.431753
# TCGA-CV-A45Q              0.510580              0.541959
# TCGA-DH-5140              0.326992              0.382290
#
#               CCAGCTCTGTGGTGCCTCCA  CAGCTCTGTGGTGCCTCCAG  \
# TCGA-TM-A84O              0.864927              0.869948
# TCGA-BF-AAP2              0.678472              0.683378
# TCGA-EJ-7794              0.392979              0.396085
# TCGA-CV-A45Q              0.547608              0.549380
# TCGA-DH-5140              0.364427              0.369795
#
#               AGCTCTGTGGTGCCTCCAGG  GCTCTGTGGTGCCTCCAGGA  \
# TCGA-TM-A84O              0.874418              0.876536
# TCGA-BF-AAP2              0.688031              0.689780
# TCGA-EJ-7794              0.400598              0.401658
# TCGA-CV-A45Q              0.554252              0.555741
# TCGA-DH-5140              0.374651              0.374989
#
#               CTCTGTGGTGCCTCCAGGAC  TCTGTGGTGCCTCCAGGACA  \
# TCGA-TM-A84O              0.879841              0.867256
# TCGA-BF-AAP2              0.693013              0.671590
# TCGA-EJ-7794              0.403458              0.372294
# TCGA-CV-A45Q              0.557692              0.539668
# TCGA-DH-5140              0.378114              0.342357
#
#               CTGTGGTGCCTCCAGGACAT  TGTGGTGCCTCCAGGACATG  ...  \
# TCGA-TM-A84O              0.822955              0.816968  ...
# TCGA-BF-AAP2              0.625184              0.615404  ...
# TCGA-EJ-7794              0.328701              0.318111  ...
# TCGA-CV-A45Q              0.516175              0.507094  ...
# TCGA-DH-5140              0.279270              0.258549  ...
#
#               TGGGTCACTAAGGTCTGACC  GTGGGTCACTAAGGTCTGAC  \
# TCGA-TM-A84O              0.773821              0.767215
# TCGA-BF-AAP2              0.790212              0.783604
# TCGA-EJ-7794              0.663231              0.657542
# TCGA-CV-A45Q              0.634455              0.630203
# TCGA-DH-5140              0.815707              0.809067
#
#               AGTGGGTCACTAAGGTCTGA  CAGTGGGTCACTAAGGTCTG  \
# TCGA-TM-A84O              0.761722              0.743233
# TCGA-BF-AAP2              0.779781              0.765683
# TCGA-EJ-7794              0.652838              0.647018
# TCGA-CV-A45Q              0.623157              0.614100
# TCGA-DH-5140              0.804172              0.798141
#
#               GCAGTGGGTCACTAAGGTCT  AGCAGTGGGTCACTAAGGTC  \
# TCGA-TM-A84O              0.731623              0.725411
# TCGA-BF-AAP2              0.754655              0.748622
# TCGA-EJ-7794              0.636485              0.630141
# TCGA-CV-A45Q              0.604593              0.599570
# TCGA-DH-5140              0.786853              0.780655
#
#               AAGCAGTGGGTCACTAAGGT  CAAGCAGTGGGTCACTAAGG  \
# TCGA-TM-A84O              0.720123              0.706700
# TCGA-BF-AAP2              0.746858              0.732725
# TCGA-EJ-7794              0.635563              0.619899
# TCGA-CV-A45Q              0.596028              0.582907
# TCGA-DH-5140              0.777613              0.763307
#
#               ACAAGCAGTGGGTCACTAAG  ACCTGTAATCACGATGTCCA
# TCGA-TM-A84O              0.698782              0.830887
# TCGA-BF-AAP2              0.724527              0.817450
# TCGA-EJ-7794              0.609649              0.709879
# TCGA-CV-A45Q              0.573897              0.624176
# TCGA-DH-5140              0.754740              0.851302
#
# [5 rows x 2828 columns]

# %%
kmer_df = pd.read_csv('~/Data/kmer_df', header = 0, index_col = 0)
# summing up
selected_kmer = kmer_df.loc[kmer_df['kmer'].isin(W.columns)]

def sum_up(df):
    '''
    given the double normalized kmer, return the sum by KIR dataframe
    '''
    sum_df = pd.DataFrame(index = df.index, columns = selected_kmer['gene'].unique())
    for name, group in selected_kmer.groupby(by = 'gene')['kmer']:
        sum_df[name] = df[group].sum(axis = 1)
    return(sum_df)

# %%
restored_sum = sum_up(restored_df)

# %%
restored_sum
# Out:
#                  KIR2DP1     KIR2DS4     KIR2DS5    KIR2DS2     KIR2DS3  \
# TCGA-TM-A84O  213.466480   90.001659    0.817316   7.291512    0.805295
# TCGA-BF-AAP2  176.516618  105.092092    0.771942   7.832734    0.959482
# TCGA-EJ-7794  117.751203   70.801652  104.017716   9.635282   22.008737
# TCGA-CV-A45Q  151.373000   46.021912   93.469388  18.344267   91.232087
# TCGA-DH-5140  106.028554  102.054489    0.712149   8.542745    0.907787
# TCGA-DE-A0Y2  104.115215  103.669240    0.715097   8.856233    0.921935
# TCGA-DB-A64W  194.622487   98.483849    0.782929   7.116899    0.766211
# TCGA-D3-A51G  126.176161   67.050965  108.686187   8.174287    4.737685
# TCGA-EJ-A65B  180.867634   91.692383    0.795447   7.839941    0.711191
# TCGA-49-4488  489.238405   45.949843    1.135186   2.210542    4.164178
# TCGA-RD-A8N6  168.116890   60.058986   77.542673  11.197835   10.921793
# TCGA-EJ-A65D  114.016357  105.116988    0.714893   9.285638    0.939338
# TCGA-EM-A2P1   98.189486   61.769099   86.147199  10.875310   11.037403
# TCGA-HT-7608  102.676536  111.620635    0.687106   7.187890    0.868908
# TCGA-CN-4726  195.376047   97.708984    0.770767   6.574711    0.790988
# TCGA-HT-A74J  212.765443    9.456196  380.296220  58.234399  405.433973
# TCGA-16-0848  196.765402   88.298026    0.785720   4.487296    0.577490
# TCGA-S9-A7QY  236.922017   95.356280    0.841383   6.388406    0.882963
# TCGA-TQ-A7RU  182.300494   71.120146   92.209559  10.049818   11.821779
# TCGA-HT-7601  110.888587  115.349154    0.690257   7.220283    1.095944
# TCGA-E1-A7YW  128.774531  105.108673    0.751034   9.145861    1.025962
# TCGA-CZ-5988   98.501826   68.971570   97.775330  11.835382   12.077960
# TCGA-D6-A6ES  170.314341   37.968200   75.275020  16.407304   88.582449
# TCGA-DJ-A4UW  202.458663   92.658148    0.843457  10.178665    0.989192
# TCGA-BJ-A3PR  121.520552  106.647747    0.726213   8.596093    0.914607
# TCGA-E8-A437  186.288578   86.508488    9.942541  18.404249   89.867663
# TCGA-56-8623  195.053714  101.989330    0.802823   7.689176    0.917772
# TCGA-E6-A1LZ  172.178672  194.618896
# TCGA-AC-A23H  263.529953  317.705488
# TCGA-E2-A1IH  267.870715  344.357028
# TCGA-D8-A1X7  305.699266  339.271734
# TCGA-EO-A1Y5  190.216509  246.065660
# TCGA-D8-A27R  257.027561  316.614438
# TCGA-E9-A228  224.410929  269.691509
# TCGA-AX-A1CP  263.318407  322.425982
# TCGA-GM-A2DM  164.777486  184.461331
# TCGA-EW-A2FS  283.555424  318.011722
# TCGA-AR-A2LM  242.932526  280.505347
# TCGA-B5-A0K8  170.617634  172.332098
# TCGA-D8-A1JM  272.473217  294.684455
# TCGA-AC-A23C  224.243580  207.878794
# TCGA-BH-A1F2  263.663794  204.365077
# TCGA-GM-A2DN  280.512897  362.000995
# TCGA-C8-A1HK  250.107536  334.609124
# TCGA-B2-4102  258.534836  436.011639
#
# [4317 rows x 12 columns]

# %%
# %matplotlib inline
color = pd.Series(index = restored_sum.columns, data = 'black')
anchor_genes = ['KIR3DL3', 'KIR3DP1', 'KIR2DL4', 'KIR3DL2']
color[anchor_genes] = 'red'
restored_sum.plot(kind = 'kde', subplots = True, figsize = (10,10), style = color.tolist())
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1055220d30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1057cc6dd8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1057b99c88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f10550a0ac8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f105657db38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1055a847f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1055a00668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f106410ea20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f106410ec88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f10576aac88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1054e22e80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f105655d828>],
#       dtype=object)

# %%
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt

# %%
def return_cutoffs(gene, w):
    kernel = gaussian_kde(w[gene])
    max_value = w[gene].max()
    # finding the values and the x axis of the fitted curve
    y = kernel(np.arange(0, max_value, max_value/float(1000)))
    x = np.arange(0, max_value, max_value/float(1000))
    
    # first derivative = 0: peaks or valleys
    dy = np.gradient(y)
    lows_index = []
    highs_index = []
    for i in range(len(dy)):
        if dy[i-1] < 0 and dy[i] >= 0:
            lows_index.append(x[i])
        elif dy[i-1] > 0 and dy[i] <= 0:
            highs_index.append(x[i])
    
    # second derivate = 0; inflection point
    inflection = []
    ddy = np.gradient(dy)
    for i in range(len(ddy)):
        if ddy[i] > 0 and ddy[i] < 0:
            inflection.append(x[i])
        elif ddy[i] < 0 and ddy[i] > 0:
            inflection.append(x[i])
    
    
    # select true peaks by values of y: at least 1/5 or the max of y
    maxium_y = max(y)
    
    new_highs = []
    for i in highs_index:
        
        if y[np.where(x == i)] > maxium_y*0.2:
            
            new_highs.append(i)
    
    # select boundary for peaks
    all_index = new_highs + lows_index
    all_index = np.sort(np.array(all_index))

    
    # smallest peak 
    lower_bound = np.asscalar(np.where(all_index == new_highs[0])[0]) - 1
    if lower_bound == -1: # sometimes the peak is the first value
        lower_bound = 0
    
    # biggest peak
    upper_bound = np.asscalar(np.where(all_index == new_highs[-1])[0]) + 1
            
    selected_index = all_index[lower_bound: upper_bound + 1]
    remove_highs = list(set(selected_index) - set(new_highs))
    remove_highs = np.sort(np.array(remove_highs)).tolist()
    
    return(x, y, remove_highs)

# %%
def assign_copy_number(gene, thres):
    thres.append(restored_sum.max()[gene]) # super upper bound
    if gene in anchor_genes + high_freq:
        if thres[0] > 1: # default
            new_thres = [0] + thres # lower bound for anchoring gene
        else:
            if gene in anchor_genes:
                new_thres = [0, 0.1] + thres[1:]
            else: 
                new_thres = [0] + thres[1:]
    else:
        new_thres = thres
    return(new_thres)

# %%
anchor_genes = ['KIR3DL3', 'KIR3DP1', 'KIR2DL4', 'KIR3DL2']
replaceable = ['KIR2DS2', 'KIR2DS3', 'KIR2DP1', 'KIR2DL1', 'KIR3DS1', 'KIR2DS5', 'KIR2DS4']
dependent = ['KIR2DS1', 'KIR2DL3', 'KIR2DL2', 'KIR3DL1', 'KIR2DL5A', 'KIR2DL5B']
high_freq = ['KIR2DP1', 'KIR2DL1', 'KIR2DS4', 'KIR2DL5']
low_freq = ['KIR2DS3', 'KIR2DS2',  'KIR2DS5', 'KIR3DS1']

gene_peaks, gene_cutoffs = {}, {}

fig, ax = plt.subplots(nrows = 12, ncols = 1, figsize = (5, 10))
i = 0
kir_copy_number = pd.DataFrame(index = restored_sum.index, columns = restored_sum.columns)
for gene in anchor_genes + high_freq + low_freq:
    x, y, thres = return_cutoffs(gene, restored_sum)
    
    
    # assign copy number
    t = assign_copy_number(gene, thres) # super big upper bound
    print(t)
    kir_copy_number[gene] = pd.cut(restored_sum[gene], t, labels = list(range(0,len(t)-1)))
    
    # plot
    ax[i].hist(restored_sum[gene], bins = 100, color = color[gene])
    for xc in t:
        ax[i].axvline(x=xc, color='grey', linestyle='--')
    ax[i].set_title(gene)
    i+=1
plt.tight_layout()
# Out:
# [0, 112.9974644773055, 387.80729808611244, 903.979715818444]
# [0, 120.02966763765387, 577.2855443525258, 2857.8492294679495]
# [0, 0.1, 470.6087177327194, 1475.2624380336033]
# [0, 8.840014594820822, 122.12316458770988, 327.4079479563268]
# [0, 126.2572197141881, 465.7867700266669, 1706.1786447863255]
# [0, 3.034704778740728, 16.97537985608095, 47.41726216782387]
# [0, 78.09602823099326, 207.01645578691864, 1239.6194957300518]
# [0, 248.5768364173481, 661.4671748732821, 4213.166718938103]
# [0.0, 55.706979276239814, 132.3679599316157, 511.0732043691726]
# [0.0, 13.80196395153503, 41.05499446600674, 116.9657961994494]
# [0.0, 42.36491807441363, 272.3459019069448, 864.5901647839516]
# [0.0, 0.5122520875274492, 2.91052322458778]

# %%
kir_copy_number.head()
# Out:
#              KIR2DP1 KIR2DS4 KIR2DS5 KIR2DS2 KIR2DS3 KIR2DL1 KIR2DL5 KIR2DL4  \
# TCGA-TM-A84O       1       1       0       0       0       1       0       1
# TCGA-BF-AAP2       1       1       0       0       0       1       0       1
# TCGA-EJ-7794       0       0       1       0       0       1       1       1
# TCGA-CV-A45Q       1       0       1       1       1       1       2       1
# TCGA-DH-5140       0       1       0       0       0       1       0       1
#
#              KIR3DS1 KIR3DL2 KIR3DL3 KIR3DP1
# TCGA-TM-A84O       0       1       1       1
# TCGA-BF-AAP2       0       1       1       1
# TCGA-EJ-7794       0       1       1       1
# TCGA-CV-A45Q       0       1       1       1
# TCGA-DH-5140       0       1       1       1

# %%
# race info
clinical = pd.read_csv('/cellar/users/ramarty/Data/hla_sex/clean_data/clinical.csv', index_col=0, header = 0)

# %%
clinical.head()
# Out:
#               Age   Sex Tissue   Race  days_to_death  days_to_last_followup  \
# TCGA-18-3406   67  Male   LUSC  white          371.0                    NaN
# TCGA-18-3407   72  Male   LUSC  asian          136.0                    NaN
# TCGA-18-3409   74  Male   LUSC  white            NaN                 2417.0
# TCGA-18-3410   81  Male   LUSC    NaN          146.0                    NaN
# TCGA-18-3416   83  Male   LUSC    NaN            NaN                  956.0
#
#              vital_status
# TCGA-18-3406         dead
# TCGA-18-3407         dead
# TCGA-18-3409        alive
# TCGA-18-3410         dead
# TCGA-18-3416        alive

# %%
def validate(race):
    freqs = pd.read_csv('/cellar/users/ramarty/Data/kir/validation/frequencies/{0}_frequencies.txt'.format(race), header=0, comment = '#')
    freqs.set_index('gene', inplace = True)
    
    race_df = kir_copy_number.loc[kir_copy_number.index.isin(clinical.loc[clinical['Race'] == race].index)]
    race_df = race_df.applymap(lambda x: x> 0)
    race_df = race_df.sum()/race_df.shape[0]*100

    freqs.loc[white.index, 'TCGA'] = race_df
    
    return(freqs)

# %%
freqs = validate('white')
freqs.dropna(inplace = True)

fig, ax = plt.subplots(figsize=(9,9))
freqs.plot(kind = 'scatter', x = 'WhitePopulation', y = 'TCGA', ax = ax)
for txt in freqs.index.tolist():
    ax.text(freqs.loc[txt, 'WhitePopulation'] , freqs.loc[txt,'TCGA'], txt)
    
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)

# %%
freqs = validate('asian')
freqs.dropna(inplace = True)

fig, ax = plt.subplots(figsize=(9,9))
freqs.plot(kind = 'scatter', x = 'AsianPopulation', y = 'TCGA', ax = ax)

for txt in freqs.index.tolist():
    ax.text(freqs.loc[txt, 'AsianPopulation'] , freqs.loc[txt,'TCGA'], txt)
    
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)

# %%
freqs = pd.read_csv('/cellar/users/ramarty/Data/kir/validation/frequencies/black_frequencies.txt', header=0, comment = '#')
freqs.set_index('gene', inplace = True)
    
race_df = kir_copy_number.loc[kir_copy_number.index.isin(clinical.loc[clinical['Race'] =='black or african american'].index)]
race_df = race_df.applymap(lambda x: x> 0)
race_df = race_df.sum()/race_df.shape[0]*100

freqs.loc[race_df.index, 'TCGA'] = race_df

# %%
freqs.plot(kind = 'scatter', x = 'AfricanPopulation', y = 'TCGA')

# %% [markdown]
# # check if specific capture kit is screwed

# %%
capture_kits = pd.read_csv('/cellar/users/ramarty/Data/kir/ref/sample.capture.kit', sep='\t')
capture_kits = capture_kits[capture_kits.SHORT_ID.isin(kir_copy_number.index)] # only select those included in study
race = 'white'
freqs = pd.read_csv('/cellar/users/ramarty/Data/kir/validation/frequencies/{0}_frequencies.txt'.format(race), header=0, comment = '#')

freqs.set_index('gene', inplace = True)
    
race_df = kir_copy_number.loc[kir_copy_number.index.isin(clinical.loc[clinical['Race'] == race].index)]
for kit in capture_kits['KIT'].unique():
    kit_df = race_df.loc[race_df.index.isin(capture_kits.loc[capture_kits['KIT'] == kit, 'SHORT_ID'])]

    kit_df = kit_df.applymap(lambda x: x> 0)
    kit_df = kit_df.sum()/kit_df.shape[0]*100

    freqs.loc[white.index, kit] = kit_df

# %%
fig, ax = plt.subplots(figsize=(9,9))

# set color
from matplotlib.cm import viridis
num_categories = len(set(capture_kits['KIT'].unique()))
colors = [viridis(float(i)/num_categories) for i in range(num_categories)]

i = 0
for kit in capture_kits['KIT'].unique():
    freqs.plot(kind = 'scatter', x = 'WhitePopulation', y = kit, ax = ax, label = kit, color = colors[i])
    i+= 1
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
