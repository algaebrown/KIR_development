# %%
merged = read.table('~/Data/liger_output/TCGA_5000_tsne.csv', header = T, sep = ',')

# %%
merged
# Out:
#      X    Row.names    X1           X2          age_at_diagnosis days_to_death
# 1     1   TCGA-02-2483   0.24410496  18.5704309 43                 -1
# 2     2   TCGA-02-2486  -2.25668712 -18.1506003 64                 -1
# 3     3   TCGA-04-1331   8.34081295  -9.7162012 78               1336
# 4     4   TCGA-04-1332  16.60796783  -3.6643776 70               1247
# 5     5   TCGA-04-1336   0.09720079  19.6045977 55                 -1
# 6     6   TCGA-04-1343 -15.07997809  23.0005065 72                361
# 7     7   TCGA-04-1346   4.16299919  17.2014461 73                 -1
# 8     8   TCGA-04-1347   8.61958024  31.3396903 81                 -1
# 9     9   TCGA-04-1356   9.25057899  20.6077371 62               1499
# 10   10   TCGA-04-1357   4.38275878  17.2410150 52                 -1
# 11   11   TCGA-04-1361  -5.30345351 -32.2780626 57                 -1
# 12   12   TCGA-04-1362   9.90777312  20.5229205 59               1348
# ...

# %%
library(tidyverse)
ggplot(data = merged) + 
  geom_point(mapping = aes(x = X1, y = X2, color = age_at_diagnosis))
# Out:
# plot without title

# %%
library(tidyverse)
ggplot(data = merged) + 
  geom_point(mapping = aes(x = X1, y = X2, color = race))
# Out:
# plot without title

# %%
library(tidyverse)
ggplot(data = merged) + 
  geom_point(mapping = aes(x = X1, y = X2, color = ethnicity))
# Out:
# plot without title

# %%
library(tidyverse)
ggplot(data = merged) + 
  geom_point(mapping = aes(x = X1, y = X2, color = tissue))
# Out:
# plot without title

# %%
library(tidyverse)
ggplot(data = merged) + 
  geom_point(mapping = aes(x = X1, y = X2, color = days_to_death))
# Out:
# plot without title

# %%
library(tidyverse)
ggplot(data = merged) + 
  geom_point(mapping = aes(x = X1, y = X2, color = gender))
# Out:
# plot without title
