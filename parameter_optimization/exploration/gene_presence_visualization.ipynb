# %%
import io
from IPython.nbformat import current
def execute_notebook(nbfile):
    with io.open(nbfile) as f:
        nb = current.read(f, 'json')
    ip = get_ipython()
    for cell in nb.worksheets[0].cells:
        if cell.cell_type != 'code':
            continue
        ip.run_cell(cell.input)
execute_notebook("/cellar/users/ramarty/Projects/kir/KIR_development/bin/imports.ipynb")
execute_notebook("/cellar/users/ramarty/Projects/kir/KIR_development/data_gathering/alternate/sample_mapping.ipynb")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# /cellar/users/ramarty/anaconda/lib/python2.7/site-packages/IPython/nbformat/current.py:19: UserWarning: IPython.nbformat.current is deprecated.
#
# - use IPython.nbformat for read/write/validate public API
# - use IPython.nbformat.vX directly to composing notebooks of a particular version
#
#   """)

# %%
df = pd.read_csv('/cellar/users/ramarty/Data/kir/components/alternate/components_four_counts.csv', index_col=0)

# %%
samples = population_dictionary_stripped[population_dictionary.keys()[4]]
df = df.ix[samples].dropna()
len(samples)
# Out:
# 94

# %% [markdown]
# What is the coverage like?

# %%
four_mers
# Out:
# ['ACGT',
#  'ACTG',
#  'AGCT',
#  'AGTC',
#  'ATCG',
#  'ATGC',
#  'CAGT',
#  'CATG',
#  'CGAT',
#  'CGTA',
#  'CTAG',
#  'CTGA',
#  'GACT',
#  'GATC',
#  'GCAT',
#  'GCTA',
#  'GTAC',
#  'GTCA',
#  'TACG',
#  'TAGC',
#  'TCAG',
#  'TCGA',
#  'TGAC',
#  'TGCA']

# %%
for mer in four_mers:
    df[[mer]].sum(axis=1).sort_values().plot()

# %%
df.sum(axis=1).sort_values().hist(bins=50, color='grey')

# %% [markdown]
# Other genes

# %%
ref_genes
# Out:
# ['PVR', 'ZNF17', 'FUT3', 'JUND', 'RAX2', 'ATP1A3', 'NOTCH3']

# %%
df[refs[ref_genes[2]]].median()
# Out:
# AGGAAACCTGCCATGGCCTC      0.0
# CCATGGCCTCCTGGTGAGCT      0.0
# CTGGTGAGCTGTCCTCATCC      0.0
# GTCCTCATCCACTGCTCGCT      1.0
# ACTGCTCGCTGCCTCTCCAG      1.0
# GCCTCTCCAGATACTCTGAC      0.0
# ATACTCTGACCCATGGATCC     29.0
# CCATGGATCCCCTGGGTGCA     16.0
# CCTGGGTGCAGCCAAGCCAC     18.0
# GCCAAGCCACAATGGCCATG     20.0
# AATGGCCATGGCGCCGCTGT     19.0
# GCGCCGCTGTCTGGCCGCAC     19.0
# CTGGCCGCACTGCTATTTCA     17.0
# TGCTATTTCAGCTGCTGGTG     14.0
# GCTGCTGGTGGCTGTGTGTT     31.0
# GCTGTGTGTTTCTTCTCCTA     74.5
# TCTTCTCCTACCTGCGTGTG     31.0
# CCTGCGTGTGTCCCGAGACG     27.0
# TCCCGAGACGATGCCACTGG     28.0
# ATGCCACTGGATCCCCTAGG     27.5
# ATCCCCTAGGGCTCCCAGTG      2.0
# GCTCCCAGTGGGTCCTCCCG      2.0
# GGTCCTCCCGACAGGACACC      3.0
# ACAGGACACCACTCCCACCC      3.5
# ACTCCCACCCGCCCCACCCT      4.0
# GCCCCACCCTCCTGATCCTG     10.0
# CCTGATCCTGCTACGGACAT      0.0
# CTACGGACATGGCCTTTCCA      0.0
# GGCCTTTCCACATCCCTGTG     56.0
# CATCCCTGTGGCTCTGTCCC     66.0
#                         ...
# ...

# %%
# 5 has some that show up across all patients
# 6 too, but at a very low level
sns.clustermap(df[refs[ref_genes[6]]].sample(200, axis=1))

# %%
kmers[20].keys()
# Out:
# [u'KIR2DP1',
#  u'KIR2DS4',
#  u'KIR2DS5',
#  u'KIR2DS2',
#  u'KIR2DS3',
#  u'KIR2DS1',
#  u'KIR2DL3',
#  u'KIR2DL2',
#  u'KIR2DL1',
#  u'KIR2DL5',
#  u'KIR2DL4',
#  u'KIR3DS1',
#  u'KIR3DL1',
#  u'KIR3DL2',
#  u'KIR3DL3',
#  u'KIR3DP1']

# %%
len(samples)
# Out:
# 94

# %%
sns.clustermap(df[kmers[20]['KIR3DL3']])

# %%
sns.heatmap(pd.DataFrame(df[kmers[20]['KIR3DL3']].median(axis=1)).sort_values(0))

# %%
df[kmers[20]['KIR3DL2']].median()
# Out:
# GTCCCTTGATGCCTGTCCTT    1.633636e-07
# CAGATGTTATGGTTCTGTTC    6.288581e-08
# AGATGTTATGGTTCTGTTCC    6.317327e-08
# GATGTTATGGTTCTGTTCCT    6.520703e-08
# ATGTTATGGTTCTGTTCCTC    6.485230e-08
# TGTTATGGTTCTGTTCCTCA    6.323100e-08
# GTTATGGTTCTGTTCCTCAC    6.317327e-08
# TTATGGTTCTGTTCCTCACT    6.209467e-08
# TATGGTTCTGTTCCTCACTC    5.605349e-08
# ATGGTTCTGTTCCTCACTCC    5.150281e-08
# TGGTTCTGTTCCTCACTCCC    5.150281e-08
# CGGTTCAGGCAGGAGAGAAC    1.190542e-07
# TAGGCTCCGTGCAGTGCCCA    1.860111e-07
# AGGCTCCGTGCAGTGCCCAA    1.977415e-07
# GGCTCCGTGCAGTGCCCAAG    1.983891e-07
# GCTCCGTGCAGTGCCCAAGG    2.002773e-07
# CTCCGTGCAGTGCCCAAGGT    1.840908e-07
# TCCGTGCAGTGCCCAAGGTC    1.776322e-07
# CCGTGCAGTGCCCAAGGTCA    1.805329e-07
# CGTGCAGTGCCCAAGGTCAA    1.819278e-07
# GTGCAGTGCCCAAGGTCAAC    1.855664e-07
# TGCAGTGCCCAAGGTCAACA    1.876128e-07
# GCAGTGCCCAAGGTCAACAG    1.895605e-07
# CAGTGCCCAAGGTCAACAGA    1.928420e-07
# AGTGCCCAAGGTCAACAGAA    2.003134e-07
# ...

# %%
for kmer in kmers[20]['KIR3DL2']:
    df[kmer].sort_values().plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-9c4258ee5ba0> in <module>()
#       1 for kmer in kmers[20]['KIR3DL2']:
# ----> 2     df[kmer].sort_values().plot(kind='scatter')
#
# /cellar/users/ramarty/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3564                            colormap=colormap, table=table, yerr=yerr,
#    3565                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3566                            **kwds)
#    3567     __call__.__doc__ = plot_series.__doc__
#    3568
#
# ...

# %%
df[kmer].sort_values().plot()

# %% [markdown]
# How do we know what samples to use as a sub-population?

# %% [markdown]
# Need a way to assign the k-mers to particular length / gene / gene combination
